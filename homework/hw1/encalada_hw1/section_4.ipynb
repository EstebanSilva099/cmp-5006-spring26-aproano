# %%
#HideToSee
#encrypted text: xqkwKBN{z0bib1wv_l3kzgxb3l_949in1i1}

c = "xqkwKBN{z0bib1wv_l3kzgxb3l_949in1i1}"

def caesar_bruteforce(ciphertext):
    alphabet = 'abcdefghijklmnopqrstuvwxyz'

    for shift in range(26):
        plaintext = ''
        for char in ciphertext:
            if char.lower() in alphabet:
                index = alphabet.index(char.lower())
                new_index = (index - shift) % 26
                new_char = alphabet[new_index]

                # conservar mayúsculas
                if char.isupper():
                    new_char = new_char.upper()

                plaintext += new_char
            else:
                plaintext += char

        print(f"Desplazamiento {shift}: {plaintext}")



caesar_bruteforce(c)
# Out:
# Desplazamiento 0: xqkwKBN{z0bib1wv_l3kzgxb3l_949in1i1}
# Desplazamiento 1: wpjvJAM{y0aha1vu_k3jyfwa3k_949hm1h1}
# Desplazamiento 2: voiuIZL{x0zgz1ut_j3ixevz3j_949gl1g1}
# Desplazamiento 3: unhtHYK{w0yfy1ts_i3hwduy3i_949fk1f1}
# Desplazamiento 4: tmgsGXJ{v0xex1sr_h3gvctx3h_949ej1e1}
# Desplazamiento 5: slfrFWI{u0wdw1rq_g3fubsw3g_949di1d1}
# Desplazamiento 6: rkeqEVH{t0vcv1qp_f3etarv3f_949ch1c1}
# Desplazamiento 7: qjdpDUG{s0ubu1po_e3dszqu3e_949bg1b1}
# Desplazamiento 8: picoCTF{r0tat1on_d3crypt3d_949af1a1}
# Desplazamiento 9: ohbnBSE{q0szs1nm_c3bqxos3c_949ze1z1}
# Desplazamiento 10: ngamARD{p0ryr1ml_b3apwnr3b_949yd1y1}
# Desplazamiento 11: mfzlZQC{o0qxq1lk_a3zovmq3a_949xc1x1}
# Desplazamiento 12: leykYPB{n0pwp1kj_z3ynulp3z_949wb1w1}
# Desplazamiento 13: kdxjXOA{m0ovo1ji_y3xmtko3y_949va1v1}
# Desplazamiento 14: jcwiWNZ{l0nun1ih_x3wlsjn3x_949uz1u1}
# Desplazamiento 15: ibvhVMY{k0mtm1hg_w3vkrim3w_949ty1t1}
# Desplazamiento 16: haugULX{j0lsl1gf_v3ujqhl3v_949sx1s1}
# Desplazamiento 17: gztfTKW{i0krk1fe_u3tipgk3u_949rw1r1}
# Desplazamiento 18: fyseSJV{h0jqj1ed_t3shofj3t_949qv1q1}
# Desplazamiento 19: exrdRIU{g0ipi1dc_s3rgnei3s_949pu1p1}
# Desplazamiento 20: dwqcQHT{f0hoh1cb_r3qfmdh3r_949ot1o1}
# Desplazamiento 21: cvpbPGS{e0gng1ba_q3pelcg3q_949ns1n1}
# Desplazamiento 22: buoaOFR{d0fmf1az_p3odkbf3p_949mr1m1}
# Desplazamiento 23: atnzNEQ{c0ele1zy_o3ncjae3o_949lq1l1}
# Desplazamiento 24: zsmyMDP{b0dkd1yx_n3mbizd3n_949kp1k1}
# Desplazamiento 25: yrlxLCO{a0cjc1xw_m3lahyc3m_949jo1j1}

# %%
import hashlib

target_hash = "82963541536fd3ea137dcf184b0786176860b6f62be2f66688b6109d04127f95"
encodings = ["utf-8", "utf-16-le", "utf-16-be", "latin-1"]
case_variants = {"original": lambda s: s, "lower": lambda s: s.lower(), "upper": lambda s: s.upper()}

try:
    with open("cheese_list.txt", "r") as f:
        cheeses = [line.strip() for line in f if line.strip()]
except FileNotFoundError:
    print("cheese_list.txt not found.")
    exit(1)

found = False
for cheese in cheeses:
    for case_name, case_func in case_variants.items():
        cheese_variant = case_func(cheese)
        for enc in encodings:
            try:
                cheese_bytes = cheese_variant.encode(enc)
            except:
                continue
            for salt in range(256):
                salt_raw = bytes([salt])
                salt_hex = format(salt, "02x").encode(enc)
                # Try appending raw and hex
                if hashlib.sha256(cheese_bytes + salt_raw).hexdigest() == target_hash:
                    print(f"✅ Match found! Cheese: {cheese}, Salt: {salt}, Method: append_raw")
                    found = True
                if hashlib.sha256(cheese_bytes + salt_hex).hexdigest() == target_hash:
                    print(f"✅ Match found! Cheese: {cheese}, Salt: {salt}, Method: append_hex")
                    found = True
                # Try prepending
                if hashlib.sha256(salt_raw + cheese_bytes).hexdigest() == target_hash:
                    print(f"✅ Match found! Cheese: {cheese}, Salt: {salt}, Method: prepend_raw")
                    found = True
                if hashlib.sha256(salt_hex + cheese_bytes).hexdigest() == target_hash:
                    print(f"✅ Match found! Cheese: {cheese}, Salt: {salt}, Method: prepend_hex")
                    found = True
                # Try inserting at every position
                for i in range(len(cheese_bytes) + 1):
                    if hashlib.sha256(cheese_bytes[:i] + salt_raw + cheese_bytes[i:]).hexdigest() == target_hash:
                        print(f"✅ Match found! Cheese: {cheese}, Salt: {salt}, Method: insert_raw at {i}")
                        found = True
                    if hashlib.sha256(cheese_bytes[:i] + salt_hex + cheese_bytes[i:]).hexdigest() == target_hash:
                        print(f"✅ Match found! Cheese: {cheese}, Salt: {salt}, Method: insert_hex at {i}")
                        found = True
                if found:
                    break
            if found:
                break
    if found:
        break

if not found:
    print("No match found.")
# Out:
# ✅ Match found! Cheese: Cabecou, Salt: 190, Method: append_raw
# ✅ Match found! Cheese: Cabecou, Salt: 190, Method: insert_raw at 7

# %%
#substitution2
import re
from collections import Counter

def solve_substitution_cipher(ciphertext, known_mappings):
    """
    Solve a substitution cipher using frequency analysis and known mappings
    """
    # Convert to lowercase for analysis (but preserve case for flag)
    cipher_lower = ciphertext.lower()
    
    # Initial mapping from known plaintext
    mapping = {}
    reverse_mapping = {}
    
    # Add known mappings from "sxzqZNV" = "picoCTF"
    # Note: We need to handle case carefully
    known_pairs = [
        ('s', 'p'), ('x', 'i'), ('z', 'c'), ('q', 'o'),
        ('Z', 'C'), ('N', 'T'), ('V', 'F')
    ]
    
    for cipher_char, plain_char in known_pairs:
        mapping[cipher_char] = plain_char
        reverse_mapping[plain_char.lower()] = cipher_char.lower()
    
    # English letter frequencies (most common to least)
    english_freq = ['e', 't', 'a', 'o', 'i', 'n', 's', 'h', 'r', 'd', 
                    'l', 'c', 'u', 'm', 'w', 'f', 'g', 'y', 'p', 'b',
                    'v', 'k', 'j', 'x', 'q', 'z']
    
    # Count frequencies in ciphertext (excluding already mapped letters)
    cipher_counts = Counter(c for c in cipher_lower if c.isalpha() and c not in mapping)
    
    # Sort cipher letters by frequency
    sorted_cipher = [item[0] for item in cipher_counts.most_common()]
    
    # Create a list of unused English letters
    used_plains = [v.lower() for v in mapping.values() if isinstance(v, str)]
    available_plains = [c for c in english_freq if c not in used_plains]
    
    # Tentatively map remaining letters by frequency
    temp_mapping = mapping.copy()
    for i, cipher_char in enumerate(sorted_cipher):
        if cipher_char not in temp_mapping and i < len(available_plains):
            temp_mapping[cipher_char] = available_plains[i]
    
    # Function to decode with current mapping
    def decode(text, mapping_dict):
        result = []
        for char in text:
            if char.isalpha():
                if char.isupper():
                    # Try uppercase mapping, fallback to lowercase mapping then uppercase
                    if char in mapping_dict:
                        result.append(mapping_dict[char])
                    elif char.lower() in mapping_dict:
                        result.append(mapping_dict[char.lower()].upper())
                    else:
                        result.append('_')
                else:
                    if char in mapping_dict:
                        result.append(mapping_dict[char])
                    else:
                        result.append('_')
            else:
                result.append(char)
        return ''.join(result)
    
    # Decode with current mapping
    decoded = decode(ciphertext, temp_mapping)
    
    # Extract the flag part (between { and })
    flag_match = re.search(r'\{([^}]+)\}', decoded)
    if flag_match:
        inner_flag = flag_match.group(1)
        # The flag should be in the format picoCTF{...}
        full_flag = f"picoCTF{{{inner_flag}}}"
        return full_flag, decoded
    
    return decoded, temp_mapping

# Read the ciphertext
ciphertext = """...{L6Y4G_4L41H515_15_73B10W5_8F1KV808}"""

# Solve
flag, full_decoded = solve_substitution_cipher(ciphertext, {})

print("Predicted flag:", flag)
print("\nFull decoded text (first 500 chars):")
print(full_decoded)
# Out:
# Predicted flag: picoCTF{N6R4W_4N41V515_15_73G10U5_8E1KF808}
#
# Full decoded text (first 500 chars):
# ...{N6R4W_4N41V515_15_73G10U5_8E1KF808}
